# %%
import pickle
import os
from pprint import pprint
from pathlib import Path

# %%
os.path.join(Path.cwd().parent, 'experiment_data', 'search-data-ss-e1-r2-p0.80000-t3-n10-s35.pkl')
# Out:
# 'd:\\College 2\\sem 3\\LTH\\code\\lth-efficiency\\experiment_data\\search-data-ss-e1-r2-p0.80000-t3-n10-s35.pkl'

# %%
with open('D:/College 2/sem 3/LTH/code/lth-efficiency/experiment_data/subnetworks-e1-r2-p0.8000-t3-s35.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
with open('D:/College 2/sem 3/LTH/code/lth-efficiency/experiment_data/search-data-ss-e1-r2-p0.8000-t3-n10-s35.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
pprint(list(results.keys()))
# Out:
# ['seeds',
#  'config',
#  'FC-train-losses',
#  'FC-train-accs',
#  'FC-test-losses',
#  'FC-test-accs',
#  'winning-tickets',
#  'winning-tickets-full-initializations',
#  'winning-ticket-masks',
#  'pruned-train-loss-before',
#  'pruned-train-acc-before',
#  'pruned-test-loss-before',
#  'pruned-test-acc-before',
#  'pruned-train-loss-after',
#  'pruned-train-acc-after',
#  'pruned-test-loss-after',
#  'pruned-test-acc-after',
#  'searchexp-train-loss',
#  'searchexp-train-acc',
#  'searchexp-test-loss',
#  'searchexp-test-acc',
#  'search-hits']
